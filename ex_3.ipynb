# %% [markdown]
# <a href="https://colab.research.google.com/github/rfahrn/Exercise_3/blob/main/ex_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic Modelling with BERTopic
#
# Taken from:
#
# https://maartengr.github.io/BERTopic/index.html
#
# https://hackernoon.com/nlp-tutorial-topic-modeling-in-python-with-bertopic-372w35l9

# %%
# !pip install bertopic
from bertopic import BERTopic

# %% [markdown]
# ## Load the data
#
# We start by extracting topics from the well-known 20 newsgroups dataset containing English documents:

# %%
from sklearn.datasets import fetch_20newsgroups

# The data needs to be a list
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
# Out:
# "\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n"

# %% [markdown]
# ## Create the model
# `.fit_transform()` fits the model to the data, generates the topics, and returns the topics with the data. It can take around half an hour.
#
# Optional arguments for `BERTopic()`:
# - `verbose=true`
# - `nr_topics=20`
# - `nr_topics='auto'`
# - `language='German'`
# - `language='multilingual'` supports 50+ languages

# %%
topic_model = BERTopic()  

topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)
#      Topic  Count                               Name
# 0       -1   6546                   -1_to_of_and_the
# 1        0   1832               0_game_team_games_he
# 2        1    569      1_key_clipper_chip_encryption
# 3        2    533              2_ites_hello_cheek_hi
# 4        3    454            3_drive_scsi_drives_ide
# ..     ...    ...                                ...
# 213    212     10           212_ear_wax_ears_syringe
# 214    213     10       213_icon_icons_click_program
# 215    214     10  214_religion_religious_wars_dogma
# 216    215     10          215_law_jesus_god_sabbath
# 217    216     10   216_board_wires_pins_motherboard
#
# [218 rows x 3 columns]

# %% [markdown]
# ## Select top topics
#
# We can now access the frequent topics that were generated:

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                               Name
# 0       -1   6546                   -1_to_of_and_the
# 1        0   1832               0_game_team_games_he
# 2        1    569      1_key_clipper_chip_encryption
# 3        2    533              2_ites_hello_cheek_hi
# 4        3    454            3_drive_scsi_drives_ide
# ..     ...    ...                                ...
# 213    212     10           212_ear_wax_ears_syringe
# 214    213     10       213_icon_icons_click_program
# 215    214     10  214_religion_religious_wars_dogma
# 216    215     10          215_law_jesus_god_sabbath
# 217    216     10   216_board_wires_pins_motherboard
#
# [218 rows x 3 columns]

# %% [markdown]
# -1 refers to all outliers and should typically be ignored. We can look at the size of topics in descending order (we use `.head(11)` because we're ignoring -1):

# %%
topic_model.get_topic_freq().head(11)
# Out:
#     Topic  Count
# 0      -1   6546
# 1       0   1832
# 2       1    569
# 3       2    533
# 4       3    454
# 5       4    450
# 6       5    329
# 7       6    328
# 8       7    265
# 9       8    185
# 10      9    169

# %% [markdown]
# ## Select one topic
#
# You can select a specific topic and get the top n words for that topic and their c-TF-IDF scores.

# %%
topic_model.get_topic(0)
# Out:
# [('game', 0.01037988667299007),
#  ('team', 0.009040690955853959),
#  ('games', 0.007202051400546848),
#  ('he', 0.007079899520713731),
#  ('players', 0.0063152731728265445),
#  ('season', 0.006258325596614474),
#  ('hockey', 0.0061343588212836985),
#  ('play', 0.005791802025830788),
#  ('25', 0.005657570761628978),
#  ('year', 0.005629384769157129)]

# %% [markdown]
# ## Topic modelling visualisation
#
# Let's look at three methods of visualisation. See https://maartengr.github.io/BERTopic/index.html for a list of all methods.
#
# # Visualise topics
#
# `visualize_topics()` shows the topics with their sizes and corresponding words.

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
# %% [markdown]
# # Visualise terms
#
# `visualize_barchart()` will show the selected terms for a few topics by creating bar charts out of the c-TF-IDF scores. You can then compare topic representations to each other and gain more insights from the topic generated.

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d1ff1136-14a5-45d2-9b66-6b61af170d18" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1ff1136-14a5-45d2-9b66-6b61af170d18")) {                    Plotly.newPlot(                        "d1ff1136-14a5-45d2-9b66-6b61af170d18",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.0063152731728265445,0.007079899520713731,0.007202051400546848,0.009040690955853959,0.01037988667299007],"y":["players  ","he  ","games  ","team  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.00930946564404836,0.011437999818041182,0.011498443390992152,0.01199533499874951,0.013684367061014049],"y":["keys  ","encryption  ","chip  ","clipper  ","key  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.25828884214739,0.2938749519637721,0.34752428773254995,0.3549289584825812,0.37295205295541856],"y":["yep  ","hi  ","cheek  ","hello  ","ites  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01724128337411315,0.017998226161424043,0.020622130890178045,0.024793017557373023,0.03390521441733345],"y":["disk  ","ide  ","drives  ","scsi  ","drive  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.01013120800916075,0.012107807875415025,0.012934633950917682,0.013825660355757339,0.015662948510344644],"y":["compound  ","fire  ","koresh  ","batf  ","fbi  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.010169652773983363,0.010688225926063699,0.013976759586553216,0.01841604465839735,0.0238022555887037],"y":["jews  ","arabs  ","arab  ","israeli  ","israel  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.008442488573765384,0.01067786755273695,0.01208631307026913,0.01324822978515983,0.024264304172111794],"y":["mustang  ","ford  ","engine  ","cars  ","car  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.008108655706730573,0.008868844022333148,0.01071001182503953,0.011879113494295455,0.015345873189403609],"y":["lane  ","my  ","ride  ","riding  ","bike  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666 ...

# %% [markdown]
# # Visualise topic similarity
#
# You can also visualize how similar certain topics are to each other.

# %%
topic_model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f2e1ec93-37a3-4581-a501-ae1032f5ef19" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2e1ec93-37a3-4581-a501-ae1032f5ef19")) {                    Plotly.newPlot(                        "f2e1ec93-37a3-4581-a501-ae1032f5ef19",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_to_of_and","0_game_team_games","1_key_clipper_chip","2_ites_hello_cheek","3_drive_scsi_drives","4_fbi_batf_koresh","5_israel_israeli_arab","6_car_cars_engine","7_bike_riding_ride","8_amp_audio_condition","9_jpeg_image_gif","10_bike_tires_bikes","11_printer_print_hp","12_gun_guns_firearms","13_health_tobacco_cesarean","14_window_widget_application","15_msg_food_chinese","16_moral_objective_morality","17_monitor_monitors_vga","18_armenian_armenians_turkish","19_den_polygon_points","20_islam_quran_islamic","21_simms_simm_vram","22_pain_migraine_drug","23_dos_pom_cds","24_ftp_data_available","25_games_joystick_sega","26_serbs_stephanopoulos_mus...","27_modem_fax_modems","28_jews_nazis_nazi","29_book_books_anania","30_windows_os2_nt","31_homosexuality_homosexual...","32_posts_post_you","33_tax_taxes_income","34_candida_yeast_infection","35_db_mov_windows","36_drivers_driver_card","37_deleted_stuff_joke","38_sky_advertising_billboard","39_diesel_diesels_fuel","40_judas_books_scripture","41_ham_radio_interference","42_kinsey_sex_men","43_theory_universe_larsons","44_hell_eternal_god","45_remote_xdm_rx","46_symbol_error_undefined","47_colormap_gc_color","48_radar_detector_detectors","49_mary_her_she","50_mouse_driver_mice","51_copy_protection_program","52_meg_drive_ram","53_wiring_wire_neutral","54_3d_grafsys_shading","55_mhz_bus_486dx250","56_wax_paint_plastic","57_space_launch_venus","58_jehovah_elohim_lord","59_were_they_armenians","60_phone_dial_number","61_hst_reboost_mission","62_kuwait_iraq_iran","63_hotel_voucher_package","64_greek_greece_turkish","65_militia_amendment_arms","66_motherboard_ram_mb","67_openwindows_motif_xview","68_mhz_fpu_clock","69_battery_batteries_concrete","70_drugs_drug_cocaine","71_moon_prize_lunar","72_newsgroup_vote_votes","73_insurance_geico_car","74_dog_dogs_bike","75_clutch_shift_transmission","76_tape_backup_tapes","77_oort_cloud_grbs","78_atheists_atheism_atheist","79_mbytes_windows_dos","80_trial_boomer_cement","81_kirlian_photography_leaf","82_schools_silence_moment","83_smiley_bolick_maddi","84_government_libertarians_...","85_guide_shipping_manuals","86_fan_cpu_heat","87_penalty_cruel_death","88_key_des_ripem","89_ra_satan_god","90_water_dept_phd","91_countersteering_bike_lean","92_fonts_font_tt","93_christianity_life_christ...","94_duo_clock_date","95_gay_sexual_homosexuals","96_god_atheism_atheists","97_marriage_married_marry","98_insurance_health_private","99_oil_drain_car","100_graphics_ray_keyboard","101_clinton_panicking_bush","102_scanner_logitech_ocr","103_board_connector_chip","104_com3_irq_port","105_dealer_price_std","106_1st_wolverine_comics","107_modem_dce_cts","108_tomb_jesus_resurrection","109_ye_verse_lord","110_km_constant_orbit","111_celp_speech_dsp","112_maxaxaxaxaxaxaxaxaxaxax...","113_hacker_computer_hackers","114_monitor_off_turn","115_hb_firearms_nra","116_xv_copyright_donation","117_truth_absolute_bible","118_helmet_liner_foam","119_dos_cluster_fat","120_lock_kryptonite_cable","121_pds_nubus_lc","122_shaft_wheelie_wheelies","123_ghostscript_postscript_...","124_scope_scopes_generator","125_odometer_sensor_speedo","126_aaron_baptism_sin","127_mode_modes_vesa","128_myers_stephanopoulos_pr...","129_memory_machine_error","130_nasa_ssf_reston","131_lens_camera_nikon","132_cancer_medical_center","133_quicktime_frames_playback","134_lyme_disease_infectious","135_professors_schools_univ...","136_ ...

# %% [markdown]
# ## Reducing topics
#
# If you didn't use the `nr_topics` argument before training, you can also reduce the number of topics after training if you want to avoid re-training.

# %%
new_topics, new_probs = topic_model.reduce_topics(docs, topics, probs, nr_topics=15)

# %% [markdown]
# ## Make a prediction
#
# To predict a topic of a new document, you need to add a new instance(s) on the `transform()` method.

# %%
topics, probs = topic_model.transform(new_docs)

# %% [markdown]
# ## Save the model
#
# After generating topics and their probabilities (i.e. training the model), we can save it to avoid our having to train the model every time we want to tweak something.

# %%
topic_model.save('my_topic_model')

# %% [markdown]
# ## Load the model

# %%
trained_model = BERTopic.load('my_topic_model')
